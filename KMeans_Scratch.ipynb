# %%
import pandas as pd 
import numpy as np

import warnings 
warnings.simplefilter('ignore')

# %%
df = pd.read_csv(r"C:\Users\omkar\OneDrive\Desktop\Datasets\players_22.csv")

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
features = ['overall','potential','value_eur','wage_eur','age']

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1         188545  https://sofifa.com/player/188545/robert-lewand...
# 2          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3         190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4         192985  https://sofifa.com/player/192985/kevin-de-bruy...
# ...          ...                                                ...
# 19234     261962  https://sofifa.com/player/261962/defu-song/220002
# 19235     262040  https://sofifa.com/player/262040/caoimhin-port...
# 19236     262760  https://sofifa.com/player/262760/nathan-logue/...
# 19237     262820  https://sofifa.com/player/262820/luke-rudden/2...
# 19238     264540  https://sofifa.com/player/264540/emanuel-lalch...
#
#                short_name                            long_name  \
# 0                L. Messi       Lionel Andrés Messi Cuccittini
# ...

# %%
df.dropna(subset=features,inplace = True)

# %%
df =  df[features].copy()

# %%
df
# Out:
#        overall  potential    value_eur  wage_eur  age
# 0           93         93   78000000.0  320000.0   34
# 1           92         92  119500000.0  270000.0   32
# 2           91         91   45000000.0  270000.0   36
# 3           91         91  129000000.0  270000.0   29
# 4           91         91  125500000.0  350000.0   30
# ...        ...        ...          ...       ...  ...
# 19234       47         52      70000.0    1000.0   22
# 19235       47         59     110000.0     500.0   19
# 19236       47         55     100000.0     500.0   21
# 19237       47         60     110000.0     500.0   19
# 19238       47         60     110000.0     500.0   19
#
# [19165 rows x 5 columns]

# %% [raw]
# 1.Scale the data
# 2.Initialize the random centroids
# 3.Label each data point to the centroids
# 4.Update the centroids

# %%
# 1.Scalling
(df.loc[0,'overall']-df['overall'].min()) /(df['overall'].max() - df['overall'].min()) *9 + 1
# Out:
# 10.0

# %%
df = ((df-df.min()) / (df.max() - df.min())) * 9 + 1

# %%
df.describe()
# Out:
#             overall     potential     value_eur      wage_eur           age
# count  19165.000000  19165.000000  19165.000000  19165.000000  19165.000000
# mean       4.670472      5.319998      1.131826      1.219443      4.063345
# std        1.346635      1.191076      0.353229      0.501528      1.575838
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        3.739130      4.521739      1.021620      1.012876      2.666667
# 50%        4.717391      5.304348      1.044817      1.064378      4.000000
# 75%        5.500000      6.086957      1.092370      1.193133      5.333333
# max       10.000000     10.000000     10.000000     10.000000     10.000000

# %%
df.head()
# Out:
#      overall  potential  value_eur   wage_eur       age
# 0  10.000000   9.608696   4.618307   9.227468  7.000000
# 1   9.804348   9.413043   6.543654   7.939914  6.333333
# 2   9.608696   9.217391   3.087308   7.939914  7.666667
# 3   9.608696   9.217391   6.984396   7.939914  5.333333
# 4   9.608696   9.217391   6.822018  10.000000  5.666667

# %%
# It selects the random points from the column in our case that is out centroid. 
df['overall'].sample()
# Out:
# 15473    3.543478
# Name: overall, dtype: float64

# %%
# def cen(x):
#     return x.sample() It is too slow and also it is giving the dataframe. we need series
# It generates the centoids randomly for every column
def random_centroids(df,k):
    centroids = []
    for i in range(k):
        centroid = df.apply(lambda x: float(x.sample()))
        centroids.append(centroid)
    return pd.concat(centroids,axis=1)

# %%
centroids = random_centroids(df,5)

# %%
centroids 
# These are the clusters
# Out:
#                   0         1         2         3         4
# overall    5.891304  3.934783  5.500000  5.500000  3.934783
# potential  4.130435  7.065217  4.326087  2.956522  6.478261
# value_eur  1.019300  1.059895  1.013501  1.008861  1.023939
# wage_eur   1.527897  1.012876  1.630901  1.038627  1.090129
# age        3.333333  6.000000  2.333333  4.000000  2.333333

# %% [raw]
#  3.Label each data point to the centroids
#  Finding the cluster labels for each data point

# %%
# Find out the distance from each element to all clusters i.e centroinds choose
# which one has min value distance
# Axis =1 means column
def get_labels(df,centroids):
    distances = centroids.apply(lambda x: np.sqrt(((df-x) ** 2).sum(axis = 1)))
    # It will return the column name or number if the entire has the min value
    return distances.idxmin(axis=1)

# %%
distances
# Out:
#                0          1          2          3          4
# 0      13.401141  12.362332  12.576295  11.512556  11.559190
# 1      12.918312  11.889529  11.885882  11.207564  11.219615
# 2      12.221888  11.099163  11.535643   9.960919  10.022989
# 3      12.665433  11.671312  11.537576  11.250888  11.257400
# 4      13.907993  13.001771  12.915167  12.526889  12.551473
# ...          ...        ...        ...        ...        ...
# 19234   4.141173   4.748431   4.891372   5.667359   5.532037
# 19235   2.823662   4.088705   3.875642   5.776142   5.400512
# 19236   3.544962   4.397216   4.425539   5.600830   5.357456
# 19237   2.648787   4.017874   3.780646   5.739577   5.325566
# 19238   2.648787   4.017874   3.780646   5.739577   5.325566
#
# [19165 rows x 5 columns]

# %%
labels = get_labels(df,centroids)

# %%
labels
# These are the column name with the minimu distance or the player i.e row belongs to which group or cluster.
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 19234    3
# 19235    4
# 19236    3
# 19237    4
# 19238    4
# Length: 19165, dtype: int64

# %%
labels.value_counts()
# Out:
# 4    7703
# 0    4509
# 3    3720
# 1    2780
# 2     453
# Name: count, dtype: int64

# %% [markdown]
# 4.Update the centroids
# Finding the geometric mean not the mean

# %%
df
# Out:
#          overall  potential  value_eur   wage_eur       age
# 0      10.000000   9.608696   4.618307   9.227468  7.000000
# 1       9.804348   9.413043   6.543654   7.939914  6.333333
# 2       9.608696   9.217391   3.087308   7.939914  7.666667
# 3       9.608696   9.217391   6.984396   7.939914  5.333333
# 4       9.608696   9.217391   6.822018  10.000000  5.666667
# ...          ...        ...        ...        ...       ...
# 19234   1.000000   1.586957   1.002830   1.012876  3.000000
# 19235   1.000000   2.956522   1.004686   1.000000  2.000000
# 19236   1.000000   2.173913   1.004222   1.000000  2.666667
# 19237   1.000000   3.152174   1.004686   1.000000  2.000000
# 19238   1.000000   3.152174   1.004686   1.000000  2.000000
#
# [19165 rows x 5 columns]

# %%
# grouped by external array of labels and apply mean for that group ie.cluster
# For exapme 0th row in the df belongs 3 cluster and also the rows that are aassociated with 3 are grouped together then mean.
def new_centroids(df,labels,k):
    return df.groupby(labels).apply(lambda x: np.exp(np.log(x).mean())).T

# %%
# new_centroids(df,labels,k)

# %%
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt 
from IPython.display import clear_output

# %%
def plot_clusters(data, labels, centroids, iteration):
    pca = PCA(n_components=2)
    data_2d = pca.fit_transform(data)
    centroids_2d = pca.transform(centroids.T)
    clear_output(wait=True)
    plt.title(f'Iteration {iteration}')
    plt.scatter(x=data_2d[:,0], y=data_2d[:,1], c=labels)
    plt.scatter(x=centroids_2d[:,0], y=centroids_2d[:,1])
    plt.show()

# %%
max_iterations = 100
centroid_count = 4

centroids = random_centroids(df, centroid_count)
old_centroids = pd.DataFrame()
iteration = 1

while iteration < max_iterations and not centroids.equals(old_centroids):
    old_centroids = centroids
    
    labels = get_labels(df, centroids)
    centroids = new_centroids(df, labels, centroid_count)
    plot_clusters(df, labels, centroids, iteration)
    iteration += 1

# %%
centroids
# Out:
#                   0         1         2         3
# overall    2.583541  4.642364  6.405155  4.311694
# potential  4.283190  4.369041  6.512406  5.838660
# value_eur  1.013460  1.035494  1.369797  1.062916
# wage_eur   1.017366  1.088135  1.614006  1.074427
# age        2.483590  5.435779  4.445231  2.700703

# %%
df[labels==0]
# Out:
#         overall  potential  value_eur  wage_eur       age
# 11593  4.326087   3.934783   1.032058  1.115880  2.666667
# 12250  4.130435   3.739130   1.022779  1.000000  2.666667
# 12643  4.130435   4.130435   1.028579  1.000000  3.333333
# 12871  4.130435   4.130435   1.028579  1.010300  3.333333
# 13552  3.934783   4.326087   1.026259  1.038627  3.666667
# ...         ...        ...        ...       ...       ...
# 19234  1.000000   1.586957   1.002830  1.012876  3.000000
# 19235  1.000000   2.956522   1.004686  1.000000  2.000000
# 19236  1.000000   2.173913   1.004222  1.000000  2.666667
# 19237  1.000000   3.152174   1.004686  1.000000  2.000000
# 19238  1.000000   3.152174   1.004686  1.000000  2.000000
#
# [2947 rows x 5 columns]

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(4)
kmeans.fit(df)
# Out:
# KMeans(n_clusters=4)

# %%
pd.DataFrame(kmeans.cluster_centers_, columns=features).T
# Out:
#                   0         1         2         3
# overall    4.231352  3.428213  6.037716  5.618764
# potential  4.209334  5.284649  6.694945  5.243238
# value_eur  1.031616  1.032393  1.417647  1.093676
# wage_eur   1.056235  1.034573  1.607417  1.278688
# age        4.689772  2.464252  3.668743  6.178785

# %%
centroids
# Out:
#                   0         1         2         3
# overall    2.583541  4.642364  6.405155  4.311694
# potential  4.283190  4.369041  6.512406  5.838660
# value_eur  1.013460  1.035494  1.369797  1.062916
# wage_eur   1.017366  1.088135  1.614006  1.074427
# age        2.483590  5.435779  4.445231  2.700703
