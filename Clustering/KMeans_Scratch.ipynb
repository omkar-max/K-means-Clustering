# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = np.random.multivariate_normal([-2,-2],[[1.0,0],[0,1.0]],50)
b = np.random.multivariate_normal([-2,-2],[[1.0,0],[0,1.0]],50)

# %%
a,b
# Out:
# (array([[-0.64928022, -1.66702902],
#         [ 0.05246029, -1.54653793],
#         [-1.82726668, -3.07504137],
#         [-2.71884344, -4.01906598],
#         [-1.47501149, -2.94368629],
#         [-1.78672047, -2.84273474],
#         [-0.24536105, -1.47473854],
#         [ 0.16429714, -1.74887078],
#         [-0.8379563 , -0.05291895],
#         [-2.47322838, -1.0689484 ],
#         [-1.9005279 , -4.01855651],
#         [-1.21713302, -2.52631615],
#         [-1.1136271 , -0.92134118],
#         [-3.2356078 , -0.41312509],
#         [-0.86653705, -3.02018847],
#         [-3.20182942, -1.40126449],
#         [-2.02677721, -2.51730488],
#         [-2.52586059, -2.92070174],
#         [-1.30882242, -1.08550095],
#         [-1.35443338, -2.69835138],
#         [ 0.00908304, -0.55818219],
#         [-3.15437589, -2.5777442 ],
#         [-2.12606194, -1.35662431],
#         [-2.07707842, -1.67748183],
#         [-2.7260171 , -1.92452176],
#         [-2.39801294,  0.6393256 ],
# ...
